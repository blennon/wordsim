# %%
x = linspace(0,2.1,1000)
x = linspace(0,12.5,1000)
plot(x, 2*exp(x) - exp(1.1*(x-.5)))
xlim([6,12.5])
# Out:
# (6, 12.5)

# %%
figure(figsize(1,8))
x = linspace(0,12.5,1000)
plot(x, 2*exp(x) - exp(1.1*(x-.5)))
xlim([6,12.5])
# Out:
# (6, 12.5)

# %%
def f(a,b):
    return (a*b - log(a))/(a-1)

# %%
f(1.2,.7)
# Out:
# 3.2883922160302279
